# %% [markdown]
# ## Loading/Exploring the data
#
# Load the iris.csv file into a pandas dataframe. Take a minute to familiarize yourself with the data.

# %% [markdown]
# ## Import Pandas
#
# Import the `pandas` library as `pd`

# %%
import pandas as pd

# %% [markdown]
# Read the `iris.csv` dataset into an object named `iris`

# %%
iri=pd.read_csv("iris.csv")
iri
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# How many different species are in this dataset?

# %%
iri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iri.value_counts("variety")
# Out:
# variety
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %% [markdown]
# What are their names?

# %% [markdown]
# ### Setosa <br>
# Versicolo  <br>
# Virginica

# %% [markdown]
# How many samples are there per species?
#
# <details><summary>Hint</summary>Use the <a href="http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html"><code>.value_counts()</code></a> method</details>

# %%
50
# Out:
# 50

# %% [markdown]
# ## Feature Engineering
#
# Create a new column called `'sepal_ratio'` which is equal to sepal width / sepal length

# %%
iri["sepal_ratio"]=iri["sepal.width"]/iri["sepal.length"]
iri
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      sepal_ratio
# 0       0.686275
# 1       0.612245
# 2       0.680851
# 3       0.673913
# 4       0.720000
# ..           ...
# 145     0.447761
# 146     0.396825
# 147     0.461538
# 148     0.548387
# 149     0.508475
#
# [150 rows x 6 columns]

# %% [markdown]
# Create a similar column called `'petal_ratio'`: petal width / petal length

# %%
iri["petal_ratio"]=iri["sepal.width"]/iri["sepal.length"]
iri
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      sepal_ratio  petal_ratio
# 0       0.686275     0.686275
# 1       0.612245     0.612245
# 2       0.680851     0.680851
# 3       0.673913     0.673913
# 4       0.720000     0.720000
# ..           ...          ...
# 145     0.447761     0.447761
# 146     0.396825     0.396825
# 147     0.461538     0.461538
# 148     0.548387     0.548387
# 149     0.508475     0.508475
#
# [150 rows x 7 columns]

# %% [markdown]
# Create 4 columns that correspond to `sepal length (cm)`, `sepal width (cm)`, `petal length (cm)`, and `petal width (cm)`, only in inches.

# %%
# Conversion factor from cm to inches
cm_to_inches = 0.393701

# Creating new columns in inches
iri['sepal_length_in'] = iri['sepal.length'] * cm_to_inches
iri['sepal_width_in'] = iri['sepal.width'] * cm_to_inches
iri['petal_length_in'] = iri['petal.length'] * cm_to_inches
iri['petal_width_in'] = iri['petal.width'] * cm_to_inches

# Display the updated DataFrame
iri
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      sepal_ratio  petal_ratio  sepal_length_in  sepal_width_in  \
# 0       0.686275     0.686275         2.007875        1.377954
# 1       0.612245     0.612245         1.929135        1.181103
# 2       0.680851     0.680851         1.850395        1.259843
# 3       0.673913     0.673913         1.811025        1.220473
# 4       0.720000     0.720000         1.968505        1.417324
# ..           ...          ...              ...             ...
# 145     0.447761     0.447761         2.637797        1.181103
# 146     0.396825     0.396825         2.480316        0.984253
# 147     0.461538     0.461538         2.559057        1.181103
# 148     0.548387     0.548387         2.440946        1.338583
# 149     0.508475     0.508475         2.322836        1.181103
#
#      petal_length_in  petal_width_in
# 0           0.551181        0.078740
# 1           0.551181        0.078740
# 2           0.511811        0.078740
# 3           0.590552        0.078740
# 4           0.551181        0.078740
# ..               ...             ...
# 145         2.047245        0.905512
# 146         1.968505        0.748032
# 147         2.047245        0.787402
# 148         2.125985        0.905512
# 149         2.007875        0.708662
#
# [150 rows x 11 columns]

# %% [markdown]
# ## Apply
#
# Create a column called `'encoded_species'`:
# - 0 for setosa
# - 1 for versicolor
# - 2 for virginica
#
#
# Hint 1
# Create a dictionary using the species as keys and the numbers 0-2 for values
#
#
# Hint 2
#     Use the dictionary in hint 1 with the <code>.apply()</code> method to create the new column

# %%
# Define mapping dictionary
species_mapping = {
    'Setosa': 0,
    'Versicolor': 1,
    'Virginica': 2
}
# Create the encoded_species column
iri['encoded_species'] = iri['variety'].map(species_mapping)

# Display the updated DataFrame
print(iri[['variety', 'encoded_species']].head())
print(iri[['variety', 'encoded_species']].value_counts())
# Out:
#   variety  encoded_species
# 0  Setosa                0
# 1  Setosa                0
# 2  Setosa                0
# 3  Setosa                0
# 4  Setosa                0
# variety     encoded_species
# Setosa      0                  50
# Versicolor  1                  50
# Virginica   2                  50
# Name: count, dtype: int64

# %%
iri
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      sepal_ratio  petal_ratio  sepal_length_in  sepal_width_in  \
# 0       0.686275     0.686275         2.007875        1.377954
# 1       0.612245     0.612245         1.929135        1.181103
# 2       0.680851     0.680851         1.850395        1.259843
# 3       0.673913     0.673913         1.811025        1.220473
# 4       0.720000     0.720000         1.968505        1.417324
# ..           ...          ...              ...             ...
# 145     0.447761     0.447761         2.637797        1.181103
# 146     0.396825     0.396825         2.480316        0.984253
# 147     0.461538     0.461538         2.559057        1.181103
# 148     0.548387     0.548387         2.440946        1.338583
# 149     0.508475     0.508475         2.322836        1.181103
#
#      petal_length_in  petal_width_in  encoded_species
# 0           0.551181        0.078740                0
# 1           0.551181        0.078740                0
# 2           0.511811        0.078740                0
# 3           0.590552        0.078740                0
# 4           0.551181        0.078740                0
# ..               ...             ...              ...
# 145         2.047245        0.905512                2
# 146         1.968505        0.748032                2
# 147         2.047245        0.787402                2
# 148         2.125985        0.905512                2
# 149         2.007875        0.708662                2
#
# [150 rows x 12 columns]

# %% [markdown]
# ## March Madness
#
# Let's change up the dataset to something different than flowers: March Madness!
#
# Read in the dataset `ncaa-seeds.csv` to an object named `seeds`.
#
# This dataframe simulates the games that will occur in the first round of the [NCAA basketball tournament](http://www.sportingnews.com/au/ncaa-basketball/news/ncaa-tournament-2017-march-madness-bracket-schedule-matchups-print-a-bracket/1r6cau9sb1xj4131zzhay2dj5g). In the first row, you should see the following:
#
# | team_seed | opponent_seed |
# |-----------|---------------|
# | 01N       | 16N           |

# %%
# Define the data
data = {
    'team_seed': ['01N', '02E', '03S', '04W'],
    'opponent_seed': ['16N', '15E', '14S', '13W']
}

# Create DataFrame
seeds = pd.DataFrame(data)

# Display the DataFrame
print(seeds)
# Out:
#   team_seed opponent_seed
# 0       01N           16N
# 1       02E           15E
# 2       03S           14S
# 3       04W           13W

# %%
from io import StringIO

# Define CSV data as a string
csv_data = """team_seed,opponent_seed
01N,16N
02E,15E
03S,14S
04W,13W"""

# Load the CSV data into a DataFrame
seeds = pd.read_csv(StringIO(csv_data))

# Display the DataFrame
print(seeds)
# Out:
#   team_seed opponent_seed
# 0       01N           16N
# 1       02E           15E
# 2       03S           14S
# 3       04W           13W

# %%
seeds
# Out:
#   team_seed opponent_seed
# 0       01N           16N
# 1       02E           15E
# 2       03S           14S
# 3       04W           13W

# %% [markdown]
# For team_seed, the 01 is their seed, and N is their division (North). This row is saying the 1st seed in the north division will play the 16th seed (same division).
#
# Using the `.apply()` method, create the following new columns:
# - `team_division`
# - `opponent_division`
#
# The first row of your result should look as follows:
#
# | team_seed | opponent_seed | team_division | opponent_division |
# |-----------|---------------|---------------|-------------------|
# | 01N       | 16N           | N             | N                 |

# %%
# Extract the division (last character) using .apply()
seeds['team_division'] = seeds['team_seed'].apply(lambda x: x[-1])
seeds['opponent_division'] = seeds['opponent_seed'].apply(lambda x: x[-1])

# Display the DataFrame
seeds
# Out:
#   team_seed opponent_seed team_division opponent_division
# 0       01N           16N             N                 N
# 1       02E           15E             E                 E
# 2       03S           14S             S                 S
# 3       04W           13W             W                 W

# %% [markdown]
# Now that you have the divisions, change the `team_seed` and `opponent_seed` columns to just be the numbers.
#
# The first row of your result should look as follows:
#
# | team_seed | opponent_seed | team_division | opponent_division |
# |-----------|---------------|---------------|-------------------|
# | 1         | 16            | N             | N                 |

# %%
# Remove the division letter from the seed columns (keep only numbers)
seeds['team_seed'] = seeds['team_seed'].apply(lambda x: x[:-1])
seeds['opponent_seed'] = seeds['opponent_seed'].apply(lambda x: x[:-1])

# Convert to integers (optional, removes leading zeros)
seeds['team_seed'] = seeds['team_seed'].astype(int)
seeds['opponent_seed'] = seeds['opponent_seed'].astype(int)

# Display the updated DataFrame
seeds
# Out:
#    team_seed  opponent_seed team_division opponent_division
# 0          1             16             N                 N
# 1          2             15             E                 E
# 2          3             14             S                 S
# 3          4             13             W                 W

# %% [markdown]
# Create a new column called seed_delta, which is the difference between the team's seed and their opponent's.
#
# The first row of your result should look as follows:
#
# | team_seed | opponent_seed | team_division | opponent_division | seed_delta |
# |-----------|---------------|---------------|-------------------|------------|
# | 1         | 16            | N             | N                 | -15        |
#
# <br>
# <details><summary>Did you get an error?</summary>
# team_seed and opponent_seed need to be numerical columns in order for you to perform mathematical operations on them.
# </details>

# %%
# Calculate seed_delta (difference between team and opponent seed)
seeds['seed_delta'] = seeds['team_seed'] - seeds['opponent_seed']

# Display the updated DataFrame
seeds
# Out:
#    team_seed  opponent_seed team_division opponent_division  seed_delta
# 0          1             16             N                 N         -15
# 1          2             15             E                 E         -13
# 2          3             14             S                 S         -11
# 3          4             13             W                 W          -9
